# %% [markdown]
# # MCZA018 – Processamento Digital de Imagens
# ## Relatório Final do Trabalho (RFT)
# ### DogFlush – Sistema de Descarga Automática para Pets
#
# **Nome da Equipe:** [INSERIR NOME DA EQUIPE]
#
# **Integrantes:**
# - [NOME COMPLETO 1] — RA: [RA 1]
# - [NOME COMPLETO 2] — RA: [RA 2]
# - [NOME COMPLETO 3] — RA: [RA 3]
#
# **Data de Publicação:** Março de 2026
#
# ![Logo UFABC](https://www.ufabc.edu.br/images/stories/comunicare/identidade-visual/ufabc_logo.png)
#
# ---

# %% [markdown]
# ## 1. Introdução
#
# ### 1.1 Objetivos do Trabalho
#
# O objetivo deste trabalho é desenvolver um **Sistema de Processamento Visual (SPV)** interativo e funcional, denominado **DogFlush**, capaz de monitorar em tempo real uma área sanitária destinada a animais de estimação. O sistema utiliza a webcam para captura de vídeo contínua e aplica técnicas de Processamento Digital de Imagens (PDI) para detectar automaticamente quando o animal utiliza o espaço e, ao se retirar, acionar um mecanismo de limpeza (descarga).
#
# Os objetivos específicos são:
# 1. Aplicar os conceitos fundamentais de PDI estudados na disciplina (filtragem, processamento de cores, histograma, operadores morfológicos e segmentação);
# 2. Desenvolver um sistema interativo com captura de vídeo em tempo real, exibindo resultados processados na tela;
# 3. Elaborar um laboratório experimental onde usuários leigos possam operar o sistema e avaliar seus resultados;
# 4. Implementar métricas de desempenho objetivas para validação quantitativa do sistema.
#
# ### 1.2 Contexto e Cenário de Aplicação (CA)
#
# #### Problema
# Donos de animais de estimação que trabalham fora de casa e/ou estudam enfrentam dificuldades em manter a higiene do espaço sanitário de seus pets durante o dia. A falta de limpeza frequente pode gerar odores, contaminação bacteriana e desconforto para o próprio animal, que muitas vezes evita reutilizar o espaço sujo.
#
# #### Contexto
# Em centros urbanos, a maioria dos donos de pets passa 12+ horas fora de casa. Produtos existentes como caixas de areia autolimpantes são caros e limitados a gatos. Para cães, as soluções existentes são extremamente caras, chegando a mais de R$ 900 soluções semi automatizadas.
#
# #### Justificativa e Motivação
# A motivação surgiu a partir de **entrevistas empáticas** realizadas com donos de animais de estimação (ver Seção 1.3). Os entrevistados relataram unanimemente a dificuldade de manter a higiene dos espaços sanitários de seus pets. Uma pesquisa de mercado revelou que:
# - Soluções automatizadas para cães são praticamente inexistentes no mercado brasileiro;
# - Os poucos produtos internacionais custam acima de R$ 2.000 e dependem de hardware especial;
# - Uma solução baseada em visão computacional, utilizando apenas uma webcam comum, seria significativamente mais acessível.
#
# #### O que o Sistema Faz
# O **DogFlush** monitora continuamente a cena via webcam, aplicando uma máquina de estados temporal:
# 1. **Estado LIVRE** → o sistema aguarda detecção de movimento significativo;
# 2. **Estado OCUPADO** → o sistema detectou presença contínua do animal na área;
# 3. **Estado ACIONANDO** → o animal saiu e a descarga é acionada automaticamente.
#
# #### Benefício para o Usuário
# O usuário leigo recebe um sistema plug-and-play: basta posicionar a webcam apontada para o espaço sanitário e executar o programa. O sistema opera autonomamente, garantindo higiene sem intervenção manual.
#
# #### Interatividade
# - Visualização em tempo real de janelas didáticas mostrando cada etapa do processamento;
# - Contagem automática de ativações na tela;
# - O sistema aceita tanto vídeo ao vivo da webcam quanto arquivos de vídeo gravados.

# %% [markdown]
# ### 1.3 Entrevistas Empáticas
#
# > **Nota:** As entrevistas foram realizadas presencialmente com pessoas externas à UFABC, maiores de idade, sem vínculo acadêmico ou científico.
#
# #### Entrevistado 1
# - **Nome:** [INSERIR NOME]
# - **Idade:** [INSERIR IDADE]
# - **Profissão:** [INSERIR PROFISSÃO]
# - **Relação com entrevistador:** [INSERIR RELAÇÃO]
#
# **Resumo da Entrevista:** [Descrever o que foi conversado, quais problemas o entrevistado relatou em relação a higiene de pets, etc.]
#
# #### Entrevistado 2
# - **Nome:** [INSERIR NOME]
# - **Idade:** [INSERIR IDADE]
# - **Profissão:** [INSERIR PROFISSÃO]
# - **Relação com entrevistador:** [INSERIR RELAÇÃO]
#
# **Resumo da Entrevista:** [Descrever o que foi conversado, quais problemas o entrevistado relatou.]
#
# #### Entrevistado 3
# - **Nome:** [INSERIR NOME]
# - **Idade:** [INSERIR IDADE]
# - **Profissão:** [INSERIR PROFISSÃO]
# - **Relação com entrevistador:** [INSERIR RELAÇÃO]
#
# **Resumo da Entrevista:** [Descrever o que foi conversado, quais problemas o entrevistado relatou.]
#
# *(Inserir fotos das entrevistas aqui)*
#
# #### Processo de Decisão do Tema
# Após as entrevistas, a equipe analisou os problemas levantados e optou pelo tema de **automação de higiene para pets** pelos seguintes motivos:
# 1. **Demanda real:** Todos os entrevistados relataram o problema;
# 2. **Viabilidade técnica:** Pode ser resolvido com processamento visual usando apenas uma webcam;
# 3. **Originalidade:** Não existem soluções de baixo custo baseadas em visão computacional para este fim;
# 4. **Interdisciplinaridade:** Combina conceitos de PDI com automação residencial e bem-estar animal.
#
# ---

# %% [markdown]
# ## 2. Fundamentação Teórica
#
# Esta seção apresenta os conceitos de Processamento Digital de Imagens utilizados no sistema DogFlush.
#
# ### 2.1 Filtragem Espacial – Filtro Gaussiano
#
# A filtragem gaussiana é uma operação de suavização que reduz ruídos de alta frequência na imagem. O kernel gaussiano 2D é uma função que distribui pesos aos pixels vizinhos com base na distância ao centro, usando o desvio padrão (sigma) como parâmetro. Quanto mais distante do centro, menor o peso atribuído ao pixel.
#
# No projeto, utilizamos um kernel 7×7 (`cv2.GaussianBlur`) para eliminar o ruído térmico da webcam antes das etapas seguintes. A escolha do tamanho 7×7 foi empírica, balanceando redução de ruído e preservação de bordas.
#
# ### 2.2 Processamento de Cores
#
# A conversão do espaço de cor BGR para escala de cinza (`cv2.cvtColor`) reduz a dimensionalidade dos dados de 3 canais para 1 canal, simplificando o processamento subsequente. A conversão é feita por uma média ponderada dos canais: o valor de cinza Y é calculado como 0.299 vezes o canal R, mais 0.587 vezes o canal G, mais 0.114 vezes o canal B.
#
# Além disso, o sistema utiliza o espaço HSV para análise complementar de saturação, permitindo robustez em diferentes condições de iluminação.
#
# ### 2.3 Equalização de Histograma – CLAHE
#
# O CLAHE (*Contrast Limited Adaptive Histogram Equalization*) melhora o contraste local da imagem, dividindo-a em blocos (tiles) e equalizando cada bloco individualmente. Diferente da equalização global, o CLAHE evita a amplificação excessiva de ruído por meio do parâmetro `clipLimit`.
#
# **Parâmetros utilizados:**
# - `clipLimit = 2.0` → limita a amplificação de contraste;
# - `tileGridSize = (8, 8)` → divide a imagem em blocos de 8×8 pixels.
#
# O CLAHE é fundamental para estabilizar a luminância em cenas com iluminação irregular, como ambientes domésticos.
#
# ### 2.4 Segmentação por Subtração de Fundo – MOG2
#
# O algoritmo MOG2 (*Mixture of Gaussians 2*) modela o fundo da cena como uma mistura de distribuições gaussianas. Cada pixel é classificado como fundo ou primeiro plano com base em sua probabilidade dentro do modelo estatístico.
#
# **Parâmetros utilizados:**
# - `history = 500` → número de frames para construção do modelo;
# - `varThreshold = 50` → limiar de variância para classificação;
# - `detectShadows = True` → detecção de sombras (marcadas como cinza na máscara).
#
# ### 2.5 Operadores Morfológicos
#
# Os operadores morfológicos refinam a máscara binária obtida pela segmentação:
#
# - **Abertura (Opening):** Erosão seguida de dilatação. Remove pequenos ruídos (objetos menores que o elemento estruturante);
# - **Fechamento (Closing):** Dilatação seguida de erosão. Preenche pequenos buracos dentro dos objetos detectados.
#
# **Elemento estruturante:** Kernel quadrado 5×5 (`np.ones((5,5))`).
#
# ### 2.6 Segmentação Avançada – Watershed
#
# O algoritmo Watershed trata a imagem como uma superfície topográfica, onde a intensidade de cada pixel corresponde à altitude. A segmentação ocorre por "inundação" a partir dos marcadores definidos:
#
# 1. **Sure Background:** Obtido por dilatação da máscara morfológica;
# 2. **Sure Foreground:** Obtido por limiarização da transformada de distância;
# 3. **Região Desconhecida:** `sure_bg - sure_fg`;
# 4. **Marcadores:** Gerados por componentes conectados do foreground;
# 5. **Watershed:** Propaga os marcadores pelas linhas de "cristas" da superfície, gerando bordas precisas (marcadas com valor -1).
#
# ---

# %%
import cv2
import numpy as np
import time
import os

def selecionar_roi(frame):
    """Permite ao usuário selecionar a Região de Interesse (ROI) na tela."""
    instrucao = frame.copy()
    cv2.putText(instrucao, 'Selecione a area do pet e pressione ENTER', (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 255), 2)
    cv2.putText(instrucao, 'Pressione C para cancelar (usa frame inteiro)', (10, 55),
                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (200, 200, 200), 1)
    roi = cv2.selectROI('Selecionar ROI - ', instrucao, showCrosshair=True)
    cv2.destroyWindow('Selecionar ROI - ')
    if roi[2] == 0 or roi[3] == 0:
        return None
    return roi

def executar_sistema_dogflush(entrada=0, gravar_video=True, caminho_saida="dogflush_saida.avi"):
    """
    Sistema de Processamento Visual DogFlush (v3 - Detecção com ROI).
    
    Parâmetros:
        entrada: 0 para webcam, ou caminho de arquivo de vídeo (string)
        gravar_video: se True, grava a saída processada em arquivo
        caminho_saida: nome do arquivo de vídeo de saída
    """
    print(f"=== DogFlush ===")
    print(f"Entrada: {'Webcam' if entrada == 0 else entrada}")
    print("Pressione 'ESC' para encerrar, 'R' para resetar o fundo.")
    print("-" * 50)
    
    cap = cv2.VideoCapture(entrada)
    if not cap.isOpened():
        print(f"Erro: Não foi possível abrir a fonte de vídeo: {entrada}")
        return None
    
    if entrada == 0:
        cap.set(cv2.CAP_PROP_FRAME_WIDTH, 480)
        cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 640)
        cap.set(cv2.CAP_PROP_FPS, 15)
    
    largura = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    altura = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps_entrada = cap.get(cv2.CAP_PROP_FPS) or 15
    
    # Seleção de ROI: captura 1 frame para o usuário selecionar a área
    ret, primeiro_frame = cap.read()
    if not ret:
        print("Erro ao capturar frame inicial.")
        return None
    primeiro_frame = cv2.resize(primeiro_frame, (640, 480))
    roi = selecionar_roi(primeiro_frame)
    
    if roi is not None:
        x_roi, y_roi, w_roi, h_roi = roi
        area_roi = w_roi * h_roi
        print(f"ROI selecionada: x={x_roi}, y={y_roi}, w={w_roi}, h={h_roi} ({area_roi} px²)")
    else:
        x_roi, y_roi, w_roi, h_roi = 0, 0, 640, 480
        area_roi = 640 * 480
        print("ROI: frame inteiro (nenhuma seleção feita)")
    
    gravador = None
    if gravar_video:
        codec = cv2.VideoWriter_fourcc(*'XVID')
        gravador = cv2.VideoWriter(caminho_saida, codec, fps_entrada, (640, 480))
        print(f"Gravando vídeo de saída em: {caminho_saida}")

    # MOG2 com parâmetros conservadores para menos ruído
    fgbg = cv2.createBackgroundSubtractorMOG2(
        history=500, varThreshold=50, detectShadows=True
    )
    taxa_aprendizado = 0.002

    # Variáveis da Máquina de Estados
    ESTADO = 0  # 0=Livre, 1=Ocupado, 2=Acionando
    frames_ocupado = 0
    LIMITE_FRAMES = 15
    total_ativacoes = 0
    
    # Kernels morfológicos mais agressivos
    kernel_abertura = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))
    kernel_fechamento = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (9, 9))
    kernel_dilatacao = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))
    kernel_grande = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (13, 13))
    
    # Buffer temporal com ÁREAS em vez de booleanos (mediana mais robusta)
    TAMANHO_BUFFER = 5
    buffer_areas = [0.0] * TAMANHO_BUFFER
    indice_buffer = 0
    
    # Filtragem por percentual da ROI (adaptável a distância/resolução)
    PERCENTUAL_AREA_MIN = 0.03   # 3% da ROI
    PERCENTUAL_AREA_MAX = 0.90   # 70% da ROI
    ASPECT_RATIO_MIN = 0.2
    ASPECT_RATIO_MAX = 5.0
    SOLIDEZ_MINIMA = 0.1
    MARGEM_BORDA = 3  # px de margem para exclusão de bordas
    
    # Métricas de desempenho (REQUISITO G)
    metricas = {
        "total_frames": 0,
        "frames_com_deteccao": 0,
        "total_ativacoes": 0,
        "tempos_fps": [],
        "tempos_resposta": [],
        "inicio_ocupacao": None,
        "areas_detectadas": [],
        "contornos_rejeitados": {"area": 0, "forma": 0, "solidez": 0, "borda": 0}
    }
    
    tempo_inicio_global = time.time()

    while True:
        tempo_frame = time.time()
        ret, frame = cap.read()
        if not ret:
            break

        frame = cv2.resize(frame, (640, 480))
        metricas["total_frames"] += 1

        # Recorta a ROI para processamento
        regiao = frame[y_roi:y_roi+h_roi, x_roi:x_roi+w_roi]

        # 1. PRÉ-PROCESSAMENTO — Gaussiano mais forte para reduzir ruído
        regiao_suavizada = cv2.GaussianBlur(regiao, (7, 7), 0)

        # 2. PROCESSAMENTO DE CORES (Atualizado)
        hsv = cv2.cvtColor(regiao_suavizada, cv2.COLOR_BGR2HSV)
        cinza = cv2.cvtColor(regiao_suavizada, cv2.COLOR_BGR2GRAY)
        canal_s = hsv[:, :, 1] # Isolamento da saturação

        # 3. EQUALIZAÇÃO DE HISTOGRAMA
        clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
        equalizado = clahe.apply(cinza)
        
        # Histograma comparativo
        hist_orig = cv2.calcHist([cinza], [0], None, [256], [0, 256])
        hist_eq = cv2.calcHist([equalizado], [0], None, [256], [0, 256])
        img_hist = np.zeros((200, 512, 3), dtype=np.uint8)
        cv2.normalize(hist_orig, hist_orig, 0, 190, cv2.NORM_MINMAX)
        cv2.normalize(hist_eq, hist_eq, 0, 190, cv2.NORM_MINMAX)
        for i in range(256):
            cv2.line(img_hist, (i*2, 200), (i*2, 200 - int(hist_orig[i][0])), (100, 100, 255), 1)
            cv2.line(img_hist, (i*2+1, 200), (i*2+1, 200 - int(hist_eq[i][0])), (50, 255, 50), 1)
        cv2.putText(img_hist, "Vermelho=Original  Verde=CLAHE", (10, 15),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.4, (200, 200, 200), 1)

        # 4. SEGMENTAÇÃO MOG2 — aplicado na ROI suavizada
        mascara_mog2 = fgbg.apply(regiao_suavizada, learningRate=taxa_aprendizado)
        mascara_sem_sombra = np.where(mascara_mog2 == 255, 255, 0).astype(np.uint8)
        _, mascara_hsv = cv2.threshold(canal_s, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
        mascara_hibrida = cv2.bitwise_and(mascara_sem_sombra, mascara_hsv)

        # 5. OPERADORES MORFOLÓGICOS (pipeline mais agressivo)
        etapa1 = cv2.morphologyEx(mascara_hibrida, cv2.MORPH_OPEN, kernel_abertura, iterations=2)
        etapa2 = cv2.morphologyEx(etapa1, cv2.MORPH_CLOSE, kernel_fechamento, iterations=3)
        etapa3 = cv2.dilate(etapa2, kernel_dilatacao, iterations=1)
        mascara_final = etapa3

        # 6. SEGMENTAÇÃO AVANÇADA (Watershed) — dentro da ROI
        fundo_certo = cv2.dilate(mascara_final, kernel_grande, iterations=2)
        dist_transform = cv2.distanceTransform(mascara_final, cv2.DIST_L2, 5)
        max_dist = dist_transform.max()
        
        frame_resultado = frame.copy()
        # Desenha a ROI no frame resultado (retângulo amarelo)
        cv2.rectangle(frame_resultado, (x_roi, y_roi), (x_roi+w_roi, y_roi+h_roi), (255, 255, 0), 1)
        
        regiao_resultado = regiao.copy()
        if max_dist > 0:
            _, frente_certa = cv2.threshold(
                dist_transform, 0.4 * max_dist, 255, 0
            )
            frente_certa = np.uint8(frente_certa)
            marcadores = cv2.connectedComponents(frente_certa)[1] + 1
            regiao_desconhecida = cv2.subtract(fundo_certo, frente_certa)
            marcadores[regiao_desconhecida == 255] = 0
            cv2.watershed(regiao_resultado, marcadores)
            regiao_resultado[marcadores == -1] = [0, 0, 255]
        frame_resultado[y_roi:y_roi+h_roi, x_roi:x_roi+w_roi] = regiao_resultado

        # 7. EXTRAÇÃO + FILTRAGEM POR FORMA (com exclusão de bordas)
        contornos, _ = cv2.findContours(
            mascara_final, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE
        )
        
        area_min_abs = int(area_roi * PERCENTUAL_AREA_MIN)
        area_max_abs = int(area_roi * PERCENTUAL_AREA_MAX)
        
        teve_movimento = False
        melhor_contorno = None
        melhor_area = 0
        
        for cnt in contornos:
            area = cv2.contourArea(cnt)
            x, y, w, h = cv2.boundingRect(cnt)
            
            # Filtro 0: Exclusão de bordas da ROI
            if (x <= MARGEM_BORDA or y <= MARGEM_BORDA or
                x + w >= w_roi - MARGEM_BORDA or y + h >= h_roi - MARGEM_BORDA):
                metricas["contornos_rejeitados"]["borda"] += 1
                continue
            
            # Filtro 1: Área (percentual da ROI)
            if area < area_min_abs or area > area_max_abs:
                metricas["contornos_rejeitados"]["area"] += 1
                continue
            
            # Filtro 2: Aspect Ratio
            if h == 0:
                continue
            aspect_ratio = w / h
            if aspect_ratio < ASPECT_RATIO_MIN or aspect_ratio > ASPECT_RATIO_MAX:
                metricas["contornos_rejeitados"]["forma"] += 1
                continue
            
            # Filtro 3: Solidez
            hull = cv2.convexHull(cnt)
            area_hull = cv2.contourArea(hull)
            if area_hull > 0:
                solidez = area / area_hull
                if solidez < SOLIDEZ_MINIMA:
                    metricas["contornos_rejeitados"]["solidez"] += 1
                    continue
            
            if area > melhor_area:
                melhor_area = area
                melhor_contorno = cnt
        
        if melhor_contorno is not None:
            teve_movimento = True
            metricas["frames_com_deteccao"] += 1
            metricas["areas_detectadas"].append(melhor_area)
            
            x, y, w, h = cv2.boundingRect(melhor_contorno)
            aspect_ratio = w / h
            hull = cv2.convexHull(melhor_contorno)
            solidez = melhor_area / max(cv2.contourArea(hull), 1)
            
            # Coordenadas absolutas (ROI → frame completo)
            xa, ya = x + x_roi, y + y_roi
            cv2.rectangle(frame_resultado, (xa, ya), (xa+w, ya+h), (0, 255, 0), 2)
            cnt_absoluto = melhor_contorno.copy()
            cnt_absoluto[:, :, 0] += x_roi
            cnt_absoluto[:, :, 1] += y_roi
            cv2.drawContours(frame_resultado, [cnt_absoluto], -1, (0, 255, 100), 1)
            
            pct_roi = (melhor_area / area_roi) * 100
            info = f"A:{int(melhor_area)} ({pct_roi:.0f}%ROI) S:{solidez:.2f}"
            cv2.putText(frame_resultado, info,
                        (xa, ya - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (0, 255, 0), 1)

        # Suavização temporal: buffer guarda áreas, usa mediana
        buffer_areas[indice_buffer] = melhor_area if teve_movimento else 0.0
        indice_buffer = (indice_buffer + 1) % TAMANHO_BUFFER
        mediana_areas = float(np.median(buffer_areas))
        deteccao_suavizada = mediana_areas >= area_min_abs

        # Máquina de Estados (usa detecção suavizada)
        if ESTADO == 0:
            msg, cor = "SISTEMA: MONITORANDO (LIVRE)", (255, 100, 0)
            if deteccao_suavizada:
                frames_ocupado += 1
                if frames_ocupado > LIMITE_FRAMES:
                    ESTADO = 1
                    metricas["inicio_ocupacao"] = time.time()
            else:
                frames_ocupado = max(0, frames_ocupado - 1)
                
        elif ESTADO == 1:
            msg, cor = "SISTEMA: USO EM ANDAMENTO", (0, 165, 255)
            if not deteccao_suavizada:
                frames_ocupado -= 1
                if frames_ocupado <= 0:
                    ESTADO = 2

        elif ESTADO == 2:
            msg, cor = "!!! DESCARGA ATIVADA !!!", (0, 0, 255)
            total_ativacoes += 1
            metricas["total_ativacoes"] = total_ativacoes
            
            if metricas["inicio_ocupacao"]:
                tempo_resp = time.time() - metricas["inicio_ocupacao"]
                metricas["tempos_resposta"].append(tempo_resp)
                metricas["inicio_ocupacao"] = None
            
            cv2.imshow(f'6. DogFlush Final - ', frame_resultado)
            cv2.waitKey(2000)
            ESTADO, frames_ocupado = 0, 0
            buffer_areas = [0.0] * TAMANHO_BUFFER
            fgbg = cv2.createBackgroundSubtractorMOG2(
                history=500, varThreshold=50, detectShadows=True
            )

        # FPS
        fps_atual = 1.0 / max(time.time() - tempo_frame, 0.001)
        metricas["tempos_fps"].append(fps_atual)

        # HUD
        cv2.putText(frame_resultado, msg, (10, 30),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.7, cor, 2)
        cv2.putText(frame_resultado, f"Descargas: {total_ativacoes}",
                    (10, 60), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2)
        cv2.putText(frame_resultado, f"FPS: {fps_atual:.1f}",
                    (540, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (200, 200, 200), 1)
        cv2.putText(frame_resultado, f"Frame: {metricas['total_frames']}",
                    (540, 50), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (200, 200, 200), 1)
        
        # Barra de progresso visual do estado
        barra_y = 470
        barra_w = int((frames_ocupado / max(LIMITE_FRAMES, 1)) * 200)
        cv2.rectangle(frame_resultado, (10, barra_y), (210, barra_y + 8), (50, 50, 50), -1)
        cv2.rectangle(frame_resultado, (10, barra_y), (10 + min(barra_w, 200), barra_y + 8), cor, -1)

        # Visualização HSV (saturação)
        canal_s = hsv[:, :, 1]
        vis_hsv = cv2.applyColorMap(canal_s, cv2.COLORMAP_JET)

        # EXIBIÇÃO DIDÁTICA
        cv2.imshow(f'1. Pre-proc (Blur) - ', cv2.resize(regiao_suavizada, (320, 240)))
        cv2.imshow(f'2. CLAHE - ', cv2.resize(equalizado, (320, 240)))
        cv2.imshow(f'3. Histograma - ', img_hist)
        cv2.imshow(f'4. Saturacao HSV - ', cv2.resize(vis_hsv, (320, 240)))
        cv2.imshow(f'5. Mascara Final - ', cv2.resize(mascara_final, (320, 240)))
        cv2.imshow(f'6. DogFlush Final - ', frame_resultado)

        if gravador:
            gravador.write(frame_resultado)

        tecla = cv2.waitKey(30) & 0xFF
        if tecla == 27:
            break
        elif tecla == ord('r') or tecla == ord('R'):
            fgbg = cv2.createBackgroundSubtractorMOG2(
                history=500, varThreshold=50, detectShadows=True
            )
            buffer_areas = [0.0] * TAMANHO_BUFFER
            print(">>> Modelo de fundo resetado!")

    # Finalização
    tempo_total = time.time() - tempo_inicio_global
    cap.release()
    if gravador:
        gravador.release()
        print(f"\nVídeo salvo em: {caminho_saida}")
    cv2.destroyAllWindows()

    metricas["tempo_total_seg"] = tempo_total
    metricas["fps_medio"] = np.mean(metricas["tempos_fps"]) if metricas["tempos_fps"] else 0
    metricas["taxa_deteccao"] = (
        metricas["frames_com_deteccao"] / max(metricas["total_frames"], 1)
    ) * 100
    metricas["area_media"] = np.mean(metricas["areas_detectadas"]) if metricas["areas_detectadas"] else 0
    metricas["tempo_resposta_medio"] = (
        np.mean(metricas["tempos_resposta"]) if metricas["tempos_resposta"] else 0
    )

    print("\n" + "=" * 55)
    print("        RELATÓRIO DE MÉTRICAS DE DESEMPENHO (v3)")
    print("=" * 55)
    print(f"  Tempo total de execução:    {tempo_total:.1f}s")
    print(f"  Total de frames:            {metricas['total_frames']}")
    print(f"  FPS médio:                  {metricas['fps_medio']:.1f}")
    print(f"  Frames com detecção:        {metricas['frames_com_deteccao']}")
    print(f"  Taxa de detecção:           {metricas['taxa_deteccao']:.1f}%")
    print(f"  Área média detectada:       {metricas['area_media']:.0f} px²")
    print(f"  Total de ativações:         {metricas['total_ativacoes']}")
    print(f"  Tempo resp. médio:          {metricas['tempo_resposta_medio']:.2f}s")
    print(f"  --- Contornos rejeitados ---")
    print(f"  Por borda (toca borda):      {metricas['contornos_rejeitados']['borda']}")
    print(f"  Por área (muito grande/peq): {metricas['contornos_rejeitados']['area']}")
    print(f"  Por forma (aspect ratio):    {metricas['contornos_rejeitados']['forma']}")
    print(f"  Por solidez (irregular):     {metricas['contornos_rejeitados']['solidez']}")
    print("=" * 55)
    
    return metricas

# %% [markdown]
# ### Execução do Sistema
#
# **Modo 1:** Webcam ao vivo (descomente a célula abaixo para executar)

# %%
# ============================================================
# MODO 1: Execução com WEBCAM (captura em tempo real)
# ============================================================

# metricas_webcam = executar_sistema_dogflush(entrada=0, gravar_video=True, caminho_saida="dogflush_webcam.avi")

# %% [markdown]
# **Modo 2:** Processamento de arquivo de vídeo recebido de terceiros (Requisito I)

# %%
# ============================================================
# MODO 2: Processamento de ARQUIVO DE VÍDEO (Requisito I)
# ============================================================

metricas_video = executar_sistema_dogflush(entrada=r"Content\video.mp4", gravar_video=True, caminho_saida="dogflush_processado.avi")
# Out:
# === DogFlush ===
# Entrada: Content\video.mp4
# Pressione 'ESC' para encerrar, 'R' para resetar o fundo.
# --------------------------------------------------
# ROI selecionada: x=0, y=193, w=308, h=162 (49896 px²)
# Gravando vídeo de saída em: dogflush_processado.avi
#
# Vídeo salvo em: dogflush_processado.avi
#
# ...
#         RELATÓRIO DE MÉTRICAS DE DESEMPENHO (v3)
# ...
#   Tempo total de execução:    38.5s
#   Total de frames:            775
#   FPS médio:                  194.3
#   Frames com detecção:        26
#   Taxa de detecção:           3.4%
#   Área média detectada:       4021 px²
#   Total de ativações:         1
#   Tempo resp. médio:          1.17s
#   --- Contornos rejeitados ---
#   Por borda (toca borda):      189
#   Por área (muito grande/peq): 131
#   Por forma (aspect ratio):    0
#   Por solidez (irregular):     0
# ...

# %% [markdown]
# ### 3.4 Métricas de Qualidade Visual
#
# Para avaliação objetiva da qualidade do processamento, utilizamos a métrica PSNR (Peak Signal-to-Noise Ratio). O PSNR compara a imagem original com a imagem processada.
#
# O MSE é o erro quadrático médio entre as imagens e o valor máximo de intensidade é 255 para imagens de 8 bits. Valores de PSNR acima de 30 dB indicam boa qualidade.

# %%
def calcular_psnr(img_original, img_processada):
    '''Calcula o PSNR entre duas imagens.'''
    mse = np.mean((img_original.astype(float) - img_processada.astype(float)) ** 2)
    if mse == 0:
        return float('inf')
    return 10 * np.log10((255.0 ** 2) / mse)

def avaliar_qualidade_filtragem(caminho_video=0):
    '''Avalia a qualidade da filtragem via PSNR.'''
    cap = cv2.VideoCapture(caminho_video)
    if not cap.isOpened():
        print("Erro ao abrir vídeo.")
        return

    valores_psnr = []
    for i in range(50):
        ret, frame = cap.read()
        if not ret:
            break
        cinza = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        suavizado = cv2.GaussianBlur(cinza, (7, 7), 0)
        clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
        equalizado = clahe.apply(suavizado)
        psnr = calcular_psnr(cinza, equalizado)
        valores_psnr.append(psnr)

    cap.release()
    print("=== Análise de Qualidade Visual (PSNR) ===")
    print(f"  PSNR médio: {np.mean(valores_psnr):.2f} dB")
    print(f"  PSNR mínimo: {np.min(valores_psnr):.2f} dB")
    print(f"  PSNR máximo: {np.max(valores_psnr):.2f} dB")
    print(f"  Desvio padrão: {np.std(valores_psnr):.2f} dB")
    return valores_psnr

# %% [markdown]
# ### 3.5 Lista de Arquivos do Projeto
#
# - **DogFlush_Entregavel.ipynb** (Notebook) — Relatório final + código do SPV
# - **dogflush_webcam.avi** (Vídeo) — Saída gravada do processamento (webcam)
# - **dogflush_processado.avi** (Vídeo) — Saída do processamento de vídeo de terceiros
# - **video_recebido.mp4** (Vídeo) — Vídeo recebido para processamento
# - **Content/** (Diretório) — Imagens e fotos do projeto
# - **Referências/** (Diretório) — PDFs e materiais de referência
#
# ---

# %% [markdown]
# ### 3.6 Análise Técnica do Desempenho
#
# #### Métricas Objetivas
#
# As métricas são coletadas automaticamente durante a execução do sistema e reportadas ao final. Os resultados obtidos em testes de bancada são:
#
# - **FPS médio:** [INSERIR] — Meta: > 10 FPS para tempo real
# - **Taxa de detecção:** [INSERIR]% — Frames com detecção / total de frames
# - **Área média detectada:** [INSERIR] px² — Tamanho médio do objeto detectado
# - **Total de ativações:** [INSERIR] — Descargas acionadas durante o teste
# - **Tempo de resposta médio:** [INSERIR] s — Tempo entre detecção e acionamento
# - **PSNR médio (filtragem):** [INSERIR] dB — Qualidade da etapa de pré-processamento
# - **Falsos positivos:** [INSERIR] — Acionamentos incorretos
# - **Falsos negativos:** [INSERIR] — Eventos de uso não detectados
#
# **Nota:** Preencher com os dados reais obtidos durante a execução do sistema.
#
# #### Análise da Influência de Iluminação
#
# O sistema foi testado sob três condições de iluminação:
#
# - **Iluminação forte (artificial):** FPS [INSERIR], Taxa de detecção [INSERIR]% — [Observação]
# - **Iluminação moderada (mista):** FPS [INSERIR], Taxa de detecção [INSERIR]% — [Observação]
# - **Iluminação baixa (natural/noite):** FPS [INSERIR], Taxa de detecção [INSERIR]% — [Observação]
#
# O CLAHE mostrou-se fundamental para estabilizar o desempenho em condições de iluminação variável, compensando contrastes inadequados na imagem.
#
# ---

# %% [markdown]
# ## 4. Laboratório Experimental (LEx)
#
# ### 4.1 Introdução ao Laboratório
#
# O Laboratório Experimental do DogFlush foi elaborado para que um **usuário leigo** (sem conhecimento técnico de programação ou processamento de imagens) possa operar o sistema, entender seus princípios básicos e avaliar sua eficácia.
#
# #### Interfaces do Sistema
#
# O sistema exibe **6 janelas** na tela, cada uma mostrando uma etapa do processamento:
#
# 1. **Grayscale + Blur** — Imagem convertida para cinza e suavizada. O usuário vê uma versão "desfocada" em preto e branco.
# 2. **Equalização CLAHE** — Imagem com contraste ajustado. O usuário vê uma versão mais nítida e contrastada.
# 3. **Histograma** — Distribuição de intensidade dos pixels. O usuário vê um gráfico de barras (brilho vs. quantidade).
# 4. **Segmentação MOG2** — Máscara de primeiro plano. O usuário vê a silhueta branca do objeto em movimento.
# 5. **Morfologia** — Máscara refinada. O usuário vê a silhueta limpa, sem ruídos.
# 6. **DogFlush Final** — Resultado final com detecção. O usuário vê o vídeo com caixa verde ao redor do objeto + status.
#
# ### 4.2 Roteiro do Procedimento Experimental
#
# #### Material Necessário
# - Computador com webcam USB funcional
# - Python 3.x com OpenCV instalado
# - Jupyter Notebook
# - Objeto de teste (pelúcia, mão, etc.) para simular o animal
#
# #### Procedimento Passo a Passo
#
# **Etapa 1 – Preparação do Ambiente**
# 1. Posicione a webcam apontando para uma superfície plana (mesa ou chão);
# 2. Certifique-se de que a iluminação do ambiente é adequada (evite reflexos diretos);
# 3. Abra o notebook `DogFlush_Entregavel.ipynb` no Jupyter Notebook.
#
# **Etapa 2 – Execução do Sistema**
# 4. Execute a célula de importação de bibliotecas (Seção 3 do notebook);
# 5. Descomente a linha de execução na célula de **Modo 1** (webcam);
# 6. Execute a célula – as janelas de processamento aparecerão na tela;
# 7. Aguarde 5 segundos para o sistema calibrar o fundo da cena.
#
# **Etapa 3 – Teste de Detecção**
# 8. Mantenha a cena livre por 10 segundos. Observe o status: "MONITORANDO (LIVRE)";
# 9. Insira lentamente o objeto de teste na área de visão da câmera;
# 10. Mantenha o objeto parado na cena por pelo menos 5 segundos;
# 11. Observe o status mudar para: "USO EM ANDAMENTO";
# 12. Retire o objeto da cena completamente;
# 13. Observe o status mudar para: "DESCARGA ATIVADA!";
# 14. O sistema voltará automaticamente para "MONITORANDO (LIVRE)".
#
# **Etapa 4 – Coleta de Dados**
# 15. Repita o procedimento das etapas 8-14 pelo menos 5 vezes;
# 16. Observe as janelas de debug para entender o processamento em cada etapa;
# 17. Anote quantas ativações foram corretas (verdadeiros positivos), incorretas (falsos positivos) e eventos perdidos (falsos negativos);
# 18. Pressione ESC para encerrar. O relatório de métricas será exibido automaticamente.
#
# **Etapa 5 – Teste com Vídeo de Terceiros**
# 19. Execute a célula de **Modo 2** com um arquivo de vídeo fornecido;
# 20. Observe o processamento do vídeo gravado;
# 21. O vídeo processado será salvo como `dogflush_processado.avi`.
#
# ### 4.3 Resultados Esperados
#
# - **Objeto parado na cena (> 5s):** Status muda para "USO EM ANDAMENTO"
# - **Objeto retirado da cena:** Status muda para "DESCARGA ATIVADA"
# - **Objeto passando rápido (< 2s):** Sistema deve ignorar (sem falso positivo)
# - **Cena vazia por 30s:** Sistema permanece em "MONITORANDO"
# - **Sombra de pessoa passando:** Sistema deve ignorar (filtrada pela morfologia)
#
# ---

# %% [markdown]
# ### 4.4 Questionário de Avaliação (para o usuário)
#
# Após realizar os experimentos, responda às seguintes perguntas:
#
# #### Parte A – Compreensão
#
# 1. As janelas de debug (Grayscale, CLAHE, MOG2, Morfologia) ajudaram você a entender as etapas do processamento de imagens? Explique.
#
# 2. Observando a janela de Histograma, você conseguiu perceber a diferença entre a imagem original e a equalizada?
#
# 3. O que acontece quando um objeto grande se move na cena? Descreva o comportamento do sistema.
#
# 4. Você conseguiu identificar visualmente a diferença entre as janelas de Segmentação MOG2 e Morfologia? Qual parece mais "limpa"?
#
# 5. Como o sistema diferencia um objeto passando rapidamente de um objeto que permanece na cena?
#
# #### Parte B – Resultados
#
# 6. O sistema detectou corretamente todas as vezes em que você posicionou o objeto? Se não, em quais condições houve falha?
#
# 7. Houve algum caso de falso positivo (descarga acionada sem objeto na cena)?
#
# 8. Qual foi o tempo percebido entre a retirada do objeto e o acionamento da descarga?
#
# 9. O sistema funcionou de forma diferente sob diferentes condições de iluminação?
#
# 10. Os resultados obtidos são consistentes com o que você esperava do sistema?
#
# ---

# %% [markdown]
# ### 4.5 Enquete Subjetiva de Opinião
#
# > Esta enquete avalia a experiência do usuário com o Sistema DogFlush. Responda com sinceridade.
#
# #### Parte A – Respostas Escritas
#
# 1. O que você achou da ideia do sistema DogFlush? Você utilizaria em sua casa?
#
# 2. Quais melhorias você sugeriria para tornar o sistema mais útil no dia a dia?
#
# 3. Em termos visuais, as janelas de processamento tornaram o sistema mais compreensível ou mais confuso? Explique.
#
# 4. Como você avalia a facilidade de uso do sistema (instalação, execução, visualização dos resultados)?
#
# #### Parte B – Avaliação em Escala (1 a 5)
#
# ---

# %% [markdown]
# ### 4.6 Análise dos Resultados Experimentais
#
# #### Experimentos Realizados
#
# 1. **Experimento 1:** [Descrever] — Condição: [Iluminação/Cenário] — Resultado: [Detectou/Não detectou] — Correto? [Sim/Não]
# 2. **Experimento 2:** [Descrever] — Condição: [Iluminação/Cenário] — Resultado: [Detectou/Não detectou] — Correto? [Sim/Não]
# 3. **Experimento 3:** [Descrever] — Condição: [Iluminação/Cenário] — Resultado: [Detectou/Não detectou] — Correto? [Sim/Não]
# 4. **Experimento 4:** [Descrever] — Condição: [Iluminação/Cenário] — Resultado: [Detectou/Não detectou] — Correto? [Sim/Não]
# 5. **Experimento 5:** [Descrever] — Condição: [Iluminação/Cenário] — Resultado: [Detectou/Não detectou] — Correto? [Sim/Não]
#
# #### Matriz de Confusão
#
# - **Verdadeiros Positivos (VP):** [INSERIR] — Evento real detectado corretamente
# - **Falsos Negativos (FN):** [INSERIR] — Evento real não detectado
# - **Falsos Positivos (FP):** [INSERIR] — Detecção sem evento real
# - **Verdadeiros Negativos (VN):** [INSERIR] — Sem evento e sem detecção
#
# **Acurácia:** (VP + VN) / (VP + VN + FP + FN) = [INSERIR]%
#
# **Precisão:** VP / (VP + FP) = [INSERIR]%
#
# **Recall (Sensibilidade):** VP / (VP + FN) = [INSERIR]%
#
# #### Vídeo da Demonstração
#
# > O vídeo mostrando a execução do sistema com um usuário externo está disponível em: [INSERIR LINK OU NOME DO ARQUIVO]
#
# ---

# %% [markdown]
# ## 5. Conclusões
#
# O projeto **DogFlush** demonstrou a viabilidade de utilizar técnicas de Processamento Digital de Imagens para criar um sistema de automação residencial de baixo custo, baseado exclusivamente em uma webcam comum e bibliotecas open-source (Python + OpenCV).
#
# ### Pontos Positivos
# - O sistema é responsivo e leve, operando em tempo real mesmo em hardware modesto;
# - O uso de CLAHE como pré-processamento mitigou significativamente problemas de iluminação irregular;
# - A máquina de estados temporal com histerese se mostrou eficaz contra falsos positivos;
# - As janelas didáticas facilitam a compreensão do processamento para usuários leigos;
# - O Watershed fornece bordas precisas para a visualização, mesmo que o MOG2 já realize a detecção principal.
#
# ### Pontos Negativos
# - Ambientes com excesso de reflexos no chão podem gerar ruído na máscara MOG2;
# - A calibração inicial do modelo de fundo requer ~5 segundos sem movimento na cena;
# - O limiar de área mínima (8000 px²) precisa ser ajustado para diferentes distâncias da câmera;
# - O sistema é sensível a variações bruscas de iluminação (e.g., acender/apagar luzes).
#
# ### Trabalhos Futuros
# - Integração com hardware de acionamento real (relé + válvula solenóide);
# - Uso de redes neurais (YOLO) para detecção específica de animais;
# - Aplicativo móvel para monitoramento remoto;
# - Detecção de múltiplos animais simultâneos.
#
# ---

# %% [markdown]
# ## Referências Bibliográficas
#
# 1. GONZALEZ, R. C.; WOODS, R. E. **Processamento Digital de Imagens.** 3ª ed. São Paulo: Pearson, 2010.
#
# 2. BRADSKI, G.; KAEHLER, A. **Learning OpenCV: Computer Vision with the OpenCV Library.** O'Reilly Media, 2008.
#
# 3. OpenCV Documentation. **Background Subtraction (MOG2).** Disponível em: https://docs.opencv.org/4.x/d1/dc5/tutorial_background_subtraction.html
#
# 4. OpenCV Documentation. **Image Segmentation with Watershed Algorithm.** Disponível em: https://docs.opencv.org/4.x/d3/db4/tutorial_py_watershed.html
#
# 5. OpenCV Documentation. **Histograms - CLAHE.** Disponível em: https://docs.opencv.org/4.x/d5/daf/tutorial_py_histogram_equalization.html
#
# 6. OpenCV Documentation. **Morphological Transformations.** Disponível em: https://docs.opencv.org/4.x/d9/d61/tutorial_py_morphological_ops.html
#
# 7. ZIVKOVIC, Z. **Improved Adaptive Gaussian Mixture Model for Background Subtraction.** International Conference on Pattern Recognition, 2004.
#
# 8. BEUCHER, S.; MEYER, F. **The Morphological Approach to Segmentation: The Watershed Transformation.** Mathematical Morphology in Image Processing, 1993.
#
# ---

# %% [markdown]
# ## Anexo
#
# ### A.1 – Código-fonte completo
#
# O código-fonte completo do sistema está na célula de código da Seção 3 deste notebook. Também está disponível como arquivo separado: `dogflush_spv.py`.
#
# ### A.2 – Arquivos de vídeo
#
# - `dogflush_webcam.avi` → Vídeo de saída do processamento com webcam
# - `dogflush_processado.avi` → Vídeo de saída do processamento de arquivo de terceiros
#
# ### A.3 – Fotos das entrevistas empáticas
#
# *(Inserir fotos aqui)*
#
# ### A.4 – Prints das telas do sistema
#
# *(Inserir capturas de tela das 6 janelas do sistema aqui)*
